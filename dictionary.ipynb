# %%
#Cpontoh program dictionary
dic= {'Dosen': 'Eko', 'Prodi' : 'Mekatronika', 'Kuliah' :'Phython'} #dibuat variabel 
#menampilkan dictionary
print("dic['Dosen']:", dic['Dosen'])
print("dic['Prodi'] :", dic['Prodi'])
print("dic['Kuliah']:", dic['Kuliah'])
# Out:
# dic['Dosen']: Eko
# dic['Prodi'] : Mekatronika
# dic['Kuliah']: Phython

# %%
dic= {'Dosen': 'Eko', 'Prodi' : 'Mekatronika', 'Kuliah' :'Phython'} #dibuat variabel 
#menampilkan dictionary
print("dic['Dosen']:", dic['Dosen'])
print("dic['Prodi'] :", dic['Prodi'])
print("dic['Kuliah']:", dic['Kuliah'])
# Out:
# dic['Dosen']: Eko
# dic['Prodi'] : Mekatronika
# dic['Kuliah']: Phython

# %%
#Variabel dictionary
dic={'satu':5, 'dua':10}
#Menampilkan Dictionary:
print("satu:", dic['satu'])
print("dua:", dic['dua'])
# Out:
# satu: 5
# dua: 10

# %%
#Variabel dictionary
dic = {'satu': 5, 'dua': 10}
print("dic['satu'] * dic['dua'] =", dic['satu'] * dic['dua'])
# Out:
# dic['satu'] * dic['dua'] = 50

# %%
#Variabel dictionary
dic = {'satu': 5, 'dua': 10}

print("satu:", dic['satu'])
print("dua:", dic['dua'])
print("satu * dua =", dic['satu'] * dic['dua'])
print("satu + dua =", dic['satu'] + dic['dua'])
print("dua - satu =", dic['dua'] - dic['satu'])
print("dua / satu =", dic['dua'] / dic['satu'])
# Out:
# satu: 5
# dua: 10
# satu * dua = 50
# satu + dua = 15
# dua - satu = 5
# dua / satu = 2.0

# %%
# Menambah Elemen ke dalam Dictionary
dic = {'satu': 5, 'dua': 10}  # sebelum ditambah
dic['tiga'] = 15              # menambah elemen key 'tiga' dan value '15'
print(dic)                    # menampilkan hasil penambahan elemen
# Out:
# {'satu': 5, 'dua': 10, 'tiga': 15}

# %%
# Mengubah Elemen dalam Dictionary
dic = {'satu': 5, 'dua': 10, 'tiga': 15}  # sebelum diubah
dic['dua'] = 20                          # mengubah value '10' menjadi '20'
print(dic)
# Out:
# {'satu': 5, 'dua': 20, 'tiga': 15}

# %%
# Menghapus Elemen dari Dictionary
dic = {'satu': 5, 'dua': 10, 'tiga': 15}  # sebelum dihapus
del dic['dua']                           # menghapus elemen dengan key 'dua'
print(dic)
# Out:
# {'satu': 5, 'tiga': 15}

# %%
# Sorting Dictionary
D = {'a': 1, 'b': 2, 'c': 3}
print(D)

# Mengambil semua key dan mengubah ke list
Ks = list(D.keys())
print(Ks)

# Mengurutkan key
Ks.sort()
print(Ks)

# Menampilkan isi dictionary berdasarkan urutan key yang sudah disortir
for key in Ks:
    print(key, '=', D[key])
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# ['a', 'b', 'c']
# ['a', 'b', 'c']
# a = 1
# b = 2
# c = 3

# %%
#Type List ( list )
# Dalam Python mirip dengan array normal
# Dalam list, elemen tidak diindeks berdasarkan kunci (key) tertentu
# Indeks bilangan selalu diawali dari nol (0)
# Indeks negatif ditentukan dari arah kanan, dan dimulai dari -1
# Bentuk umum: nama_list = [nilai1, nilai2, nilai3, ...]

# Contoh:
list = [10, 20, 30, 40, 50]

# Index elemen di dalam list berdasarkan posisi
print('Index List')
print(list[0])  # bernilai 10
print(list[2])  # bernilai 30
print(list[4])  # bernilai 50
print(list[-1]) # bernilai 50
print(list[-2]) # bernilai 40
print(list[-5]) # bernilai 10
print('Banyaknya elemen')
print(len(list))
# Out:
# Index List
# 10
# 30
# 50
# 50
# 40
# 10
# Banyaknya elemen
# 5

# %%
# Contoh
list1 = [10, 20, 30, 40, 50]
# Slicing (memotong) elemen di dalam list
print('Sebelum dipotong:')
print(list)
print('Setelah digabung:')
print(list[:-1])#memotong elemet pertama dari kanan
print(list[:1])#memotong elemet
print(list[-1:])#memotong elemet pertama dari kanan keculai element -1
print(list[-2])
# Out:
# Sebelum dipotong:
# [10, 20, 30, 40, 50]
# Setelah digabung:
# [10, 20, 30, 40]
# [10]
# [50]
# 40
